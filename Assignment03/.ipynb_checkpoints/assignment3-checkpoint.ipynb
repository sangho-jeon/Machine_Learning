# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

path = "data.csv"
data = np.genfromtxt(path, delimiter=',')

x_data = data[:, 0]
y_data = data[:, 1]

m=x_data.size

plt.figure(figsize=(8, 8))
plt.scatter(x_data, y_data, c='black', alpha=0.3)
plt.show()

# %%
def objective_function(y, hx, m):
    loss =  hx - y
    tmp = np.sum(loss)
    sqr = tmp*tmp 
    return sqr/(2*m)

def obj_f(y, t0, t1, x, m):
    hx = t0+t1*x
    loss = hx-y
    tmp = loss*loss
    sqr = np.sum(tmp)
    return sqr/(2*m)

def loss_function_theta_zero(y, hx, m):
    loss = hx - y
    tmp = np.sum(loss)
    return tmp/m


    
def loss_function_theta_one(y,hx, x, m):
    loss = (hx - y)*x
    tmp = np.sum(loss)
    return tmp/m

# %%
threshold = 5

#initial condition
theta0 = 0
theta1 = 0
hx = x_data*theta1 + theta0
#step_size 
step = 0.001
loss_list = []
loss_count = []
theta0_list = []
theta1_list = []
enough = False
count = 0 
while(enough == False):
    loss = objective_function(y_data, hx, m)
    loss_list.append(loss)
    loss_count.append(count)
    theta0_list.append(theta0)
    theta1_list.append(theta1)
    if(loss < threshold ):
        enough = True
    else:
        count = count + 1
        theta0 = theta0 - step*loss_function_theta_zero(y_data, hx, m)
        theta1 = theta1 - step*loss_function_theta_one(y_data, hx, x_data, m)
        hx = x_data*theta1 + theta0
        
print(theta0, theta1)
# Out:
# 24.68217318812857 9.931167487582362

# %%
plt.figure(figsize=(8, 8))
plt.scatter(x_data, y_data, c='black', alpha=0.3)
plt.plot([-10,10],[theta0-theta1*10, theta1*10+theta0], c='r')
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

energy_t0 = np.arange(-500, 500, 1)
energy_t1 = np.arange(-100, 100, 1)
t0, t1 = np.meshgrid(energy_t0, energy_t1)
energy_z = []

for i in energy_t1:
    line = []
    for j in energy_t0:
        line.append(obj_f(y_data, j, i, x_data, x_data.size))
    energy_z.append(line)
    

z=np.array(energy_z)
print(z)
surf = ax.plot_surface(t0,t1,z,cmap='coolwarm',linewidth=0,antialiased=True)
plt.show()
# Out:
# [[306925.79108634 306454.96350984 305985.13593334 ... 334016.69731584
#   334542.86973934 335070.04216284]
#  [303609.28408171 303137.96912636 302667.654171   ... 330214.27359278
#   330739.95863742 331266.64368207]
#  [300325.42063414 299853.61829993 299382.81596572 ... 326444.49342677
#   326969.69109256 327495.88875835]
#  ...
#  [283790.42366693 283223.58245599 282657.74124506 ... 215155.73636473
#   215585.8951538  216017.05394286]
#  [286904.69740202 286337.36881223 285771.04022244 ... 217784.09338139
#   218213.7647916  218644.43620181]
#  [290051.61469417 289483.79872552 288916.98275688 ... 220445.0939551
#   220874.27798646 221304.46201781]]
