# %%
import matplotlib.pyplot as plt 
import numpy as np

m = 100
x = [0.0, 10.0]
np.random.seed(0)
scatterx = 10*np.random.sample(m)
scattery = scatterx + np.random.normal(0,1,m)

plt.plot(x, x, c='b')
plt.scatter(scatterx, scattery ,c='black')
plt.axis([0,10,0,10])
plt.show()

# %%
#initial power

def objective_function(y, hx, m):
    loss =  hx - y
    tmp = np.sum(loss)
    tmp = tmp*tmp 
    return tmp/2*m

theta0 = 0
theta1 = 1

hx = scatterx*theta1 + theta0

a = objective_function(scattery, hx, m)
print(a)
# Out:
# 18496.249955788826
